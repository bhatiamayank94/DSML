# %%
'''
1 - Assumptions of ANOVA - use kruskal wallis test if below conditions are not met 
    Normal distribution - Normal distribution test - wilkin shapiro test
    Independent - 
    Homogeneity
2 - Check summary from the pdf below
'''

# %%
from IPython.display import IFrame, display_pdf
import pandas as pd

# %% [markdown]
# # Summary of the tests

# %%
print(IFrame(r'C:\Users\Mayank Bhatia\Documents\GitHub\DSML\9_data_analytics_and_visualisation_fundamentals\9.6_anova_2\tests_checklist.pdf', width=800, height=400))

# %% [markdown]
# # Aerofit examples

# %%
df=pd.read_csv(r'C:\Users\Mayank Bhatia\Documents\GitHub\DSML\9_data_analytics_and_visualisation_fundamentals\9.6_anova_2\aerofit.csv')
