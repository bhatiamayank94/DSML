# %%
'''
H0=Null Hypothesis  - Status quo

p value - probability probability of happening an event to conclude alternate hypthesis

type 1 errot - false negative

type 2 error - false positive

alpha  - threshold

right/left tailed test: 

'''
