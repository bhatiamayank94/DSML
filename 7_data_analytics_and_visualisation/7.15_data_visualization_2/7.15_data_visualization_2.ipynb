# %%
# tutor colab - https://colab.research.google.com/drive/1Tyoi2i61lJXff9EQ3z0GOi21my-hjwF_?usp=sharing

# %%
'''
Data viz 2

Boxplot - sns.boxplot

Iqr 

Range of iqr and outliers - 1.5*iqr

Bivariate - continuous vs continuous 

Line plot

Change limits

Compare 2 plots

Legends

Labels

Bring legends outside plot

Grid 

Scatter plot
'''

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
df_raw=pd.read_csv(r'C:\Users\28962\Documents\GitHub\DSML\7_data_analytics_and_visualisation\7.15_data_visualization_2\games.csv')

# %%
df_raw['Name'].value_counts()
# Out:
# Name
# Ice Hockey                     41
# Baseball                       17
# Need for Speed: Most Wanted    12
# FIFA 14                         9
# Madden NFL 07                   9
#                                ..
# Zoo Quest: Puzzle Fun!          1
# Zoo Resort 3D                   1
# Zoo Tycoon                      1
# Deca Sports 3                   1
# 10 Minute Solution              1
# Name: count, Length: 11493, dtype: int64

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x=df_raw['Global_Sales'])
# sns.boxplot(y=df_raw['Global_Sales'])
plt.show()

# %% [markdown]
# # Bi variate viz

# %% [markdown]
# ## line plot

# %%
df_ice_hockey=df_raw[df_raw['Name']=="Ice Hockey"]
sns.lineplot(x="Year", y="NA_Sales", data=df_ice_hockey,color="cyan")
# plt.xlim(left=1990) # use this to limit axis
plt.show()

# %%
# Adding line charts, labels, grid

df_ice_hockey=df_raw[df_raw['Name']=="Ice Hockey"]
df_baseball=df_raw[df_raw['Name']=="Baseball"]
sns.lineplot(x="Year", y="NA_Sales", data=df_ice_hockey,color="cyan",label="ice_hockey")
sns.lineplot(x="Year", y="NA_Sales", data=df_baseball,color="cornflowerblue",label="baseball") # note that values for baseball for 1981 and 1982 are null but graph doesnt fall to 0 because this is how sns handles nan values
plt.grid(visible=True)

# %%
# Labels as another line code

df_ice_hockey=df_raw[df_raw['Name']=="Ice Hockey"]
df_baseball=df_raw[df_raw['Name']=="Baseball"]
sns.lineplot(x="Year", y="NA_Sales", data=df_ice_hockey,color="cyan",label="ice_hockey")
sns.lineplot(x="Year", y="NA_Sales", data=df_baseball,color="cornflowerblue",label="baseball") # note that values for baseball for 1981 and 1982 are null but graph doesnt fall to 0 because this is how sns handles nan values
plt.grid(visible=True)
plt.legend(loc="lower left")

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(df_raw,x="Rank",y="Global_Sales")
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %% [markdown]
# # Questions
