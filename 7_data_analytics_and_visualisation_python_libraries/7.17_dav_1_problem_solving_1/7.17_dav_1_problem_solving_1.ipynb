# %%
# tutor's colab notebook  - https://colab.research.google.com/drive/1wBsDcI2ZAnuguk1ExLxZzAXxI2nHreEV?usp=sharing

import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv(r'C:\Users\28962\Documents\GitHub\DSML\7_data_analytics_and_visualisation\7.17_dav_1_problem_solving_1\games.csv')

# %%
df_top=df[(df['Genre'].isin(df['Genre'].value_counts().index[:3]))&(df['Platform'].isin(df['Platform'].value_counts().index[:3]))&(df['Publisher'].isin(df['Publisher'].value_counts().index[:3]))]

# %% [markdown]
# # NNN with hue

# %%
sns.scatterplot(size="Rank",data=df_top,x="NA_Sales",y="EU_Sales",hue="Rank")
# Out:
# <Axes: xlabel='NA_Sales', ylabel='EU_Sales'>

# %% [markdown]
# # Corr - with annot=True

# %%
df_top_3=df_top.drop(['Genre','Platform','Publisher','Name'],axis=1)

# %%
sns.heatmap(df_top_3.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # KDE plot - with and without histplot

# %%
sns.histplot(x="Year",data=df,kde=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.kdeplot(data=df,x="Year")
# Out:
# <Axes: xlabel='Year', ylabel='Density'>
