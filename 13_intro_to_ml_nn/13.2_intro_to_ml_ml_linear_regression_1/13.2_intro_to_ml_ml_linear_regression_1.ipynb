# %%
import pandas as pd
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler

# %%
df_raw=pd.read_csv(r'C:\Users\28962\Documents\GitHub\DSML\13_intro_to_ml_nn\13.2_intro_to_ml_ml_linear_regression_1\cars24-car-price.csv')
df_raw.head()
# Out:
#                                         full_name  selling_price    year  \
# 0                                 Maruti Alto Std           1.20  2012.0
# 1                          Hyundai Grand i10 Asta           5.50  2016.0
# 2                                Hyundai i20 Asta           2.15  2010.0
# 3                   Maruti Alto K10 2010-2014 VXI           2.26  2012.0
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70  2015.0
#
#   seller_type  km_driven fuel_type transmission_type  mileage  engine  \
# 0  Individual     120000    Petrol            Manual    19.70   796.0
# 1  Individual      20000    Petrol            Manual    18.90  1197.0
# 2  Individual      60000    Petrol            Manual    17.00  1197.0
# 3  Individual      37000    Petrol            Manual    20.92   998.0
# 4      Dealer      30000    Diesel            Manual    22.77  1498.0
#
#    max_power  seats
# 0      46.30    5.0
# 1      82.00    5.0
# 2      80.00    5.0
# ...

# %%
# sklearn

# target variable = selling_price

scaler=MinMaxScaler()
scaler.fit_transform(df_raw)

# min max scaler

# train-test split

# linear regression - fit

# predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10992\2710983626.py in ?()
#       2
#       3 # target variable = selling_price
#       4
#       5 scaler=MinMaxScaler()
# ----> 6 scaler.fit_transform(df_raw)
#       7
#       8 # min max scaler
#       9
#
# c:\Users\28962\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\28962\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
# ...

# %%
matplotlib.pyplot
