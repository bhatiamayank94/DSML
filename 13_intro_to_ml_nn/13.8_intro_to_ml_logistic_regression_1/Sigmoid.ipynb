# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1/(1+np.e**-x)

# %%
sigmoid(1.99)
# Out:
# 0.8797431375322491

# %%
sigmoid(-90)
# Out:
# 8.194012623990555e-40

# %%
sigmoid(9000)
# Out:
# 1.0

# %%
-9.59--9.39
# Out:
# -0.1999999999999993

# %%
x = np.linspace(-10,10,100)
y = sigmoid(x)
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("Sigmoid(X)")
plt.grid()
plt.show()

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler
import numpy as np

# Data
X = np.array([[2, 4],
              [3, 5],
              [5, 6],
              [7, 8],
              [15, 20]])  # with outlier
y = np.array([8, 11, 14, 20, 60])  # with outlier

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# L1 regularization (Lasso)
lasso_model = Lasso(alpha=0.1)  # small alpha to encourage sparsity
lasso_model.fit(X_scaled, y)
lasso_coefs = lasso_model.coef_

# L2 regularization (Ridge)
ridge_model = Ridge(alpha=0.1)  # small alpha
ridge_model.fit(X_scaled, y)
ridge_coefs = ridge_model.coef_

print("Lasso coefficients:", lasso_coefs)
print("Ridge coefficients:", ridge_coefs)
# Out:
# Lasso coefficients: [ 0.         19.01306252]
# Ridge coefficients: [ 4.9743422  13.92167722]
